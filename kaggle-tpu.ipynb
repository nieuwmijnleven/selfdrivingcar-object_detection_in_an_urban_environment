# %%
# !pip install -U tensorflow-gcs-config==2.5.0

# %%
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()
user_credential = user_secrets.get_gcloud_credential()
user_secrets.set_tensorflow_credential(user_credential)

# %%
# !git clone https://github.com/nieuwmijnleven/object_detection_in_an_urban_environment.git

# %%
# %cd /kaggle/working/object_detection_in_an_urban_environment

# %%
# !git pull

# %%
# %cd object_detection_in_an_urban_environment/training/pretrained-models

# %%
# !pwd

# %%
# !cat ssd_resnet50_v1_fpn_640x640_coco17_tpu-8.tar.gz.* > ssd_resnet50_v1_fpn_640x640_coco17_tpu-8.tar.gz

# %%
# !tar xvfz ssd_resnet50_v1_fpn_640x640_coco17_tpu-8.tar.gz

# %%
# %cd ../../

# %%
# !mkdir tensorflow

# %%
# %cd tensorflow

# %%
# !git clone https://github.com/tensorflow/models.git

# %%
# !wget https://github.com/protocolbuffers/protobuf/releases/download/v3.18.0/protoc-3.18.0-linux-x86_64.zip

# %%
# !unzip protoc-3.18.0-linux-x86_64.zip

# %%
# !pwd

# %%
# %cd models/research

# %%
# !/kaggle/working/object_detection_in_an_urban_environment/tensorflow/bin/protoc object_detection/protos/*.proto --python_out=.

# %%
# !cp object_detection/packages/tf2/setup.py .

# %%
# %cd /kaggle/working/object_detection_in_an_urban_environment/tensorflow/models/research

# %%
# !python -m pip install --use-feature=2020-resolver .

# %%
pip install google-cloud-bigquery-storage

# %%
# !pip install tensorflow==2.5.0

# %%
# !pip install tensorflow-text==2.5.0

# %%
# !python object_detection/builders/model_builder_tf2_test.py

# %%
# %cd /kaggle/working/object_detection_in_an_urban_environment

# %%
# !python experiments/model_main_tf2_tpu.py --model_dir=gs://object_detection_bucket-1/training/reference/ --pipeline_config_path=pipeline_new_tpu.config

# %%
# !python experiments/exporter_main_v2.py --input_type image_tensor --pipeline_config_path ./pipeline_new_tpu.config --trained_checkpoint_dir gs://object_detection_bucket-1/training/reference/  --output_directory gs://object_detection_bucket-1/saved_model

# %%
# !python experiments/model_main_tf2.py --model_dir gs://object_detection_bucket-1/training/reference/ --pipeline_config_path pipeline_new_tpu.config --checkpoint_dir gs://object_detection_bucket-1/training/reference/

# %%
# !tar cf saved_model.tar ./saved_model

# %%
# !ls -lh saved_model.tar

# %%
from google.colab import drive 
drive.mount('/content/gdrive')

# %%
cp saved_model.tar /content/gdrive
